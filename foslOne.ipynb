# %%
import pandas as pd
from clustergrammer_widget import *
net = Network(clustergrammer_widget)

# %%
pip install --upgrade clustergrammer
# Out:
# Requirement already up-to-date: clustergrammer in c:\users\santoshb\anaconda3\lib\site-packages (1.13.6)Note: you may need to restart the kernel to use updated packages.

# %%
from clustergrammer2 import net

# %%
# load our data
net.load_file('clustergrammer1.tsv')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-cd3e79463864> in <module>
#       1 # load our data
# ----> 2 net.load_file('clustergrammer1.tsv')
#
# ~\Anaconda3\lib\site-packages\clustergrammer2\clustergrammer_fun\__init__.py in load_file(self, filename)
#      53     Load TSV file.
#      54     '''
# ---> 55     load_data.load_file(self, filename)
#      56
#      57   def load_file_as_string(self, file_string, filename=''):
#
# ~\Anaconda3\lib\site-packages\clustergrammer2\clustergrammer_fun\load_data.py in load_file(net, filename)
#      23   f.close()
#      24
# ---> 25   load_file_as_string(net, file_string, filename)
#      26
#      27 def load_file_as_string(net, file_string, filename=''):
#
# ~\Anaconda3\lib\site-packages\clustergrammer2\clustergrammer_fun\load_data.py in load_file_as_string(net, file_string, filename)
# ...

# %%
# check shape of data
net.dat['mat'].shape
# Out:
# (191, 6)

# %%
net.cluster(views=[])
net.widget()
# Out:
# CGM2(network='{"row_nodes": [{"name": "NOP2", "ini": 191, "clust": 22, "rank": 55, "rankvar": 140}, {"name": "…
